# %% [markdown]
# Statistics is a field that deals with collection, organisation,analysis, interpretation and presentation of the data --> Decission Making

# %% [markdown]
# ![Whiteboard.png](attachment:Whiteboard.png)

# %% [markdown]
# ![3-PopulationVSsample#01.png](attachment:3-PopulationVSsample#01.png)

# %% [markdown]
# ![4-Measure+OF+Central+Tendency#01.png](attachment:4-Measure+OF+Central+Tendency#01.png)

# %% [markdown]
# Mean is increased so large when big number is added so the solution is finding median instead of mean

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![5+-+Measure+of+Dispersion+#01.png](attachment:5+-+Measure+of+Dispersion+#01.png)

# %% [markdown]
# variance is used to calculate dispersion of data means how much data is dispersed.
